# %% [markdown]
# # DeepGuard — Environment Test
#
# This notebook verifies that the Google Colab environment is ready for the DeepGuard deepfake video detection project.
#
# ### Checks
# - Python version
# - PyTorch installation
# - GPU availability
# - Google Drive connection
# - OpenCV
# - NumPy / Pandas
# - Required ML libraries

# %%
import sys

print("Python version:")
print(sys.version)
# Out:
# Python version:
# 3.9.6 (default, Apr 30 2025, 02:07:17)
# [Clang 17.0.0 (clang-1700.0.13.5)]
